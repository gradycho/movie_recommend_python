# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_contents_based_filtering_list(genre).csv'
contents_based_filtering_genre_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_contents_based_filtering_list(genre).csv')
contents_based_filtering_genre_df.head()
# Out:
#    rank  movieId                        title        title_kor  \
# 0     1      480                Jurassic Park           쥬라기 공원
# 1     2    61248                   Death Race           데스 레이스
# 2     3   127323                         Vice              바이스
# 3     4   120799           Terminator Genisys       터미네이터 제니시스
# 4     5    70336  G.I. Joe: The Rise Of Cobra  지.아이.조 - 전쟁의 서막
#
#                              genres  \
# 0  Action Adventure Sci-Fi Thriller
# 1  Action Adventure Sci-Fi Thriller
# 2  Action Adventure Sci-Fi Thriller
# 3  Action Adventure Sci-Fi Thriller
# 4  Action Adventure Sci-Fi Thriller
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20130531_210/1...
# 1  https://movie-phinf.pstatic.net/20111222_9/132...
# 2  https://movie-phinf.pstatic.net/20190322_181/1...
# 3  https://movie-phinf.pstatic.net/20150626_201/1...
# 4  https://movie-phinf.pstatic.net/20111223_92/13...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_contents_based_filtering_list(director&cast).csv'
contents_based_filtering_dc_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_contents_based_filtering_list(director&cast).csv')
contents_based_filtering_dc_df.head()
# Out:
#    rank   movieId                     title     title_kor     director  \
# 0     1  102445.0  Star Trek  Into Darkness     스타트렉 다크니스  J.J. Abrams
# 1     2   59315.0                  Iron Man          아이언맨  Jon Favreau
# 2     3  111443.0                      Chef       아메리칸 셰프  Jon Favreau
# 3     4   68358.0                 Star Trek  스타 트렉: 더 비기닝  J.J. Abrams
# 4     5    6936.0                       Elf            엘프  Jon Favreau
#
#                                              cast  \
# 0           Chris Pine,Zachary Quinto,Zoe Saldana
# 1  Robert Downey Jr.,Terrence Howard,Jeff Bridges
# 2         Jon Favreau,Sofía Vergara,Emjay Anthony
# 3         Chris Pine,Zachary Quinto,Leonard Nimoy
# 4         Will Ferrell,James Caan,Zooey Deschanel
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20130529_15/13...
# 1  https://movie-phinf.pstatic.net/20111222_37/13...
# 2  https://movie-phinf.pstatic.net/20141205_174/1...
# ...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_nearest neighbor collaborative filtering.csv'
nearest_neighbor_collaborative_filtering_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_nearest neighbor collaborative filtering.csv')
nearest_neighbor_collaborative_filtering_df.head()
# Out:
#    rank  movieId                   title         title_kor  pred_score  \
# 0     1       10               GoldenEye         007 골든 아이    4.953251
# 1     2    68954                      Up                 업    4.815590
# 2     3      329  Star Trek: Generations  스타 트랙 7 - 넥서스 트랙    4.758790
# 3     4   115617              Big Hero 6             빅 히어로    4.727632
# 4     5      434             Cliffhanger             클리프행어    4.548341
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111222_264/1...
# 1  https://movie-phinf.pstatic.net/20111223_221/1...
# 2  https://movie-phinf.pstatic.net/20130422_146/1...
# 3  https://movie-phinf.pstatic.net/20150121_287/1...
# 4  https://movie-phinf.pstatic.net/20111222_1/132...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_Latent Factor Collaborative Filtering_list.csv'
Latent_Factor_Collaborative_Filtering_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_Latent Factor Collaborative Filtering_list.csv')
Latent_Factor_Collaborative_Filtering_df.head()
# Out:
#    rank  movieId             title  title_kor  pred_score  \
# 0     1     5903       Equilibrium     이퀼리브리엄    8.208284
# 1     2      198      Strange Days  스트레인지 데이즈    8.204300
# 2     3    40819     Walk The Line        앙코르    7.971156
# 3     4   134130       The Martian         마션    7.934669
# 4     5    98961  Zero Dark Thirty   제로 다크 서티    7.811521
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111222_185/1...
# 1  https://movie-phinf.pstatic.net/20111221_91/13...
# 2  https://movie-phinf.pstatic.net/20111222_120/1...
# 3  https://movie-phinf.pstatic.net/20151014_112/1...
# 4  https://movie-phinf.pstatic.net/20130219_146/1...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_Deep Learning based Recommender Systems_list.csv'
DeepLearning_based_Recommender_Systems_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user213_영화추천리스트/213_Deep Learning based Recommender Systems_list.csv')
DeepLearning_based_Recommender_Systems_df.head()
# Out:
#    movieId                title   title_kor  \
# 0      296         Pulp Fiction       펄프 픽션
# 1      527     Schindler's List     쉰들러 리스트
# 2     2028  Saving Private Ryan  라이언 일병 구하기
# 3     2858      American Beauty     아메리칸 뷰티
# 4     2959           Fight Club      파이트 클럽
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111221_33/13...
# 1  https://movie-phinf.pstatic.net/20190122_81/15...
# 2  https://movie-phinf.pstatic.net/20111222_4/132...
# 3  https://movie-phinf.pstatic.net/20111222_29/13...
# 4  https://movie-phinf.pstatic.net/20161013_298/1...

# %%
nearest_neighbor_collaborative_filtering_df = nearest_neighbor_collaborative_filtering_df[['movieId', 'title', 'title_kor', 'poster_url']]
nearest_neighbor_collaborative_filtering_df['section'] = 1

Latent_Factor_Collaborative_Filtering_df = Latent_Factor_Collaborative_Filtering_df[['movieId', 'title', 'title_kor', 'poster_url']]
Latent_Factor_Collaborative_Filtering_df['section'] = 2

contents_based_filtering_genre_df = contents_based_filtering_genre_df[['movieId', 'title', 'title_kor', 'poster_url']]
contents_based_filtering_genre_df['section'] = 3

contents_based_filtering_dc_df = contents_based_filtering_dc_df[['movieId', 'title', 'title_kor', 'poster_url']]
contents_based_filtering_dc_df['section'] = 4

DeepLearning_based_Recommender_Systems_df = DeepLearning_based_Recommender_Systems_df[['movieId', 'title', 'title_kor', 'poster_url']]
DeepLearning_based_Recommender_Systems_df['section'] = 5
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
user213_recommend_movies = pd.concat([nearest_neighbor_collaborative_filtering_df, Latent_Factor_Collaborative_Filtering_df, contents_based_filtering_genre_df, contents_based_filtering_dc_df, DeepLearning_based_Recommender_Systems_df], axis = 0)
user213_recommend_movies['userID'] = 1
user213_recommend_movies.rename(columns={'movieId':'rec_mv_id'}, inplace=True)
user213_recommend_movies = user213_recommend_movies[['userID', 'section', 'rec_mv_id', 'title', 'title_kor', 'poster_url']]
user213_recommend_movies
# Out:
#    userID  section  rec_mv_id                        title         title_kor  \
# 0       1        1       10.0                    GoldenEye         007 골든 아이
# 1       1        1    68954.0                           Up                 업
# 2       1        1      329.0       Star Trek: Generations  스타 트랙 7 - 넥서스 트랙
# 3       1        1   115617.0                   Big Hero 6             빅 히어로
# 4       1        1      434.0                  Cliffhanger             클리프행어
# 0       1        2     5903.0                  Equilibrium            이퀼리브리엄
# 1       1        2      198.0                 Strange Days         스트레인지 데이즈
# 2       1        2    40819.0                Walk The Line               앙코르
# 3       1        2   134130.0                  The Martian                마션
# 4       1        2    98961.0             Zero Dark Thirty          제로 다크 서티
# 0       1        3      480.0                Jurassic Park            쥬라기 공원
# ...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_contents_based_filtering_list(genre).csv'
contents_based_filtering_genre_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_contents_based_filtering_list(genre).csv')
contents_based_filtering_genre_df.head()
# Out:
#    rank  movieId                            title           title_kor  \
# 0     1    88744   Rise of the Planet of the Apes        혹성탈출: 진화의 시작
# 1     2   117529                   Jurassic World              쥬라기 월드
# 2     3      292                         Outbreak              아웃브레이크
# 3     4    72378                             2012                2012
# 4     5    76130  Universal Soldier: Regeneration  유니버셜 솔저 3 - 리제너레이션
#
#                                    genres  \
# 0            Action Drama Sci-Fi Thriller
# 1  Action Adventure Drama Sci-Fi Thriller
# 2            Action Drama Sci-Fi Thriller
# 3            Action Drama Sci-Fi Thriller
# 4            Action Drama Sci-Fi Thriller
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111223_31/13...
# 1  https://movie-phinf.pstatic.net/20150522_110/1...
# 2  https://movie-phinf.pstatic.net/20111222_122/1...
# 3  https://movie-phinf.pstatic.net/20130515_275/1...
# ...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_contents_based_filtering_list(director&cast).csv'
contents_based_filtering_dc_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_contents_based_filtering_list(director&cast).csv')
contents_based_filtering_dc_df.head()
# Out:
#    rank   movieId                                         title  \
# 0     1    2028.0                           Saving Private Ryan
# 1     2   88125.0  Harry Potter And The Deathly Hallows: Part 2
# 2     3    5989.0                           Catch Me If You Can
# 3     4   68157.0                          Inglourious Basterds
# 4     5  143385.0                               Bridge of Spies
#
#             title_kor           director  \
# 0          라이언 일병 구하기   Steven Spielberg
# 1  해리 포터와 죽음의 성물 - 2부        David Yates
# 2         캐치 미 이프 유 캔   Steven Spielberg
# 3        바스터즈: 거친 녀석들  Quentin Tarantino
# 4             스파이 브릿지   Steven Spielberg
#
#                                              cast  \
# 0                 Tom Hanks,Matt Damon,Vin Diesel
# 1       Daniel Radcliffe,Rupert Grint,Emma Watson
# 2  Leonardo DiCaprio,Tom Hanks,Christopher Walken
# 3       Brad Pitt,Mélanie Laurent,Christoph Waltz
# 4                 Tom Hanks,Mark Rylance,Amy Ryan
#
# ...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_nearest neighbor collaborative filtering.csv'
nearest_neighbor_collaborative_filtering_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_nearest neighbor collaborative filtering.csv')
nearest_neighbor_collaborative_filtering_df.head()
# Out:
#    rank  movieId              title title_kor  pred_score  \
# 0     1    57669          In Bruges   킬러들의 도시    5.350492
# 1     2     4878       Donnie Darko     도니 다코    5.238015
# 2     3    85414        Source Code     소스 코드    5.048185
# 3     4     1704  Good Will Hunting    굿 윌 헌팅    4.797765
# 4     5   108932     The Lego Movie     레고 무비    4.737438
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111222_207/1...
# 1  https://movie-phinf.pstatic.net/20111222_3/132...
# 2  https://movie-phinf.pstatic.net/20111223_127/1...
# 3  https://movie-phinf.pstatic.net/20160810_49/14...
# 4  https://movie-phinf.pstatic.net/20160419_133/1...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_Latent Factor Collaborative Filtering_list.csv'
Latent_Factor_Collaborative_Filtering_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_Latent Factor Collaborative Filtering_list.csv')
Latent_Factor_Collaborative_Filtering_df.head()
# Out:
#    rank  movieId           title title_kor  pred_score  \
# 0     1     4226         Memento       메멘토    9.049829
# 1     2     1089  Reservoir Dogs   저수지의 개들    8.845394
# 2     3    57669       In Bruges   킬러들의 도시    8.780619
# 3     4      778   Trainspotting    트레인스포팅    8.751830
# 4     5    44761           Brick        브릭    8.690444
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20200804_123/1...
# 1  https://movie-phinf.pstatic.net/20111222_282/1...
# 2  https://movie-phinf.pstatic.net/20111222_207/1...
# 3  https://movie-phinf.pstatic.net/20111222_226/1...
# 4  https://movie-phinf.pstatic.net/20111222_62/13...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_Deep Learning based Recommender Systems_list.csv'
DeepLearning_based_Recommender_Systems_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user475_영화추천리스트/475_Deep Learning based Recommender Systems_list.csv')
DeepLearning_based_Recommender_Systems_df.head()
# Out:
#    movieId               title  title_kor  \
# 0      150           Apollo 13     아폴로 13
# 1      500      Mrs. Doubtfire  미세스 다웃파이어
# 2      527    Schindler's List    쉰들러 리스트
# 3      590  Dances With Wolves     늑대와 춤을
# 4      608               Fargo         파고
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111223_68/13...
# 1  https://movie-phinf.pstatic.net/20111222_82/13...
# 2  https://movie-phinf.pstatic.net/20190122_81/15...
# 3  https://movie-phinf.pstatic.net/20210106_266/1...
# 4  https://movie-phinf.pstatic.net/20111221_53/13...

# %%
nearest_neighbor_collaborative_filtering_df = nearest_neighbor_collaborative_filtering_df[['movieId', 'title', 'title_kor', 'poster_url']]
nearest_neighbor_collaborative_filtering_df['section'] = 1

Latent_Factor_Collaborative_Filtering_df = Latent_Factor_Collaborative_Filtering_df[['movieId', 'title', 'title_kor', 'poster_url']]
Latent_Factor_Collaborative_Filtering_df['section'] = 2

contents_based_filtering_genre_df = contents_based_filtering_genre_df[['movieId', 'title', 'title_kor', 'poster_url']]
contents_based_filtering_genre_df['section'] = 3

contents_based_filtering_dc_df = contents_based_filtering_dc_df[['movieId', 'title', 'title_kor', 'poster_url']]
contents_based_filtering_dc_df['section'] = 4

DeepLearning_based_Recommender_Systems_df = DeepLearning_based_Recommender_Systems_df[['movieId', 'title', 'title_kor', 'poster_url']]
DeepLearning_based_Recommender_Systems_df['section'] = 5
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
user475_recommend_movies = pd.concat([nearest_neighbor_collaborative_filtering_df, Latent_Factor_Collaborative_Filtering_df, contents_based_filtering_genre_df, contents_based_filtering_dc_df, DeepLearning_based_Recommender_Systems_df], axis = 0)
user475_recommend_movies['userID'] = 475
user475_recommend_movies.rename(columns={'movieId':'rec_mv_id'}, inplace=True)
user475_recommend_movies = user475_recommend_movies[['userID', 'section', 'rec_mv_id', 'title', 'title_kor', 'poster_url']]
user475_recommend_movies
# Out:
#    userID  section  rec_mv_id                                         title  \
# 0     475        1    57669.0                                     In Bruges
# 1     475        1     4878.0                                  Donnie Darko
# 2     475        1    85414.0                                   Source Code
# 3     475        1     1704.0                             Good Will Hunting
# 4     475        1   108932.0                                The Lego Movie
# 0     475        2     4226.0                                       Memento
# 1     475        2     1089.0                                Reservoir Dogs
# 2     475        2    57669.0                                     In Bruges
# 3     475        2      778.0                                 Trainspotting
# 4     475        2    44761.0                                         Brick
# 0     475        3    88744.0                Rise of the Planet of the Apes
# ...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_contents_based_filtering_list(genre).csv'
contents_based_filtering_genre_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_contents_based_filtering_list(genre).csv')
contents_based_filtering_genre_df.head()
# Out:
#    rank  movieId                                        title    title_kor  \
# 0     1     6156                             Shanghai Knights      상하이 나이츠
# 1     2   113348                 Teenage Mutant Ninja Turtles         닌자터틀
# 2     3    42015                                     Casanova         카사노바
# 3     4     2683        Austin Powers: The Spy Who Shagged Me       오스틴 파워
# 4     5     1517  Austin Powers: International Man Of Mystery  오스틴 파워 - 제로
#
#                                   genres  \
# 0                Action Adventure Comedy
# 1                Action Adventure Comedy
# 2  Action Adventure Comedy Drama Romance
# 3                Action Adventure Comedy
# 4                Action Adventure Comedy
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111221_80/13...
# 1  https://movie-phinf.pstatic.net/20140729_123/1...
# 2  https://movie-phinf.pstatic.net/20111222_100/1...
# ...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_contents_based_filtering_list(director&cast).csv'
contents_based_filtering_dc_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_contents_based_filtering_list(director&cast).csv')
contents_based_filtering_dc_df.head()
# Out:
#    rank   movieId                  title    title_kor          director  \
# 0     1    2028.0    Saving Private Ryan   라이언 일병 구하기  Steven Spielberg
# 1     2    5989.0    Catch Me If You Can  캐치 미 이프 유 캔  Steven Spielberg
# 2     3  143385.0        Bridge of Spies      스파이 브릿지  Steven Spielberg
# 3     4    1042.0     That Thing You Do!      댓 씽 유 두         Tom Hanks
# 4     5    1894.0  Six Days Seven Nights  식스 데이 세븐 나잇      Ivan Reitman
#
#                                              cast  \
# 0                 Tom Hanks,Matt Damon,Vin Diesel
# 1  Leonardo DiCaprio,Tom Hanks,Christopher Walken
# 2                 Tom Hanks,Mark Rylance,Amy Ryan
# 3   Tom Everett Scott,Johnathon Schaech,Tom Hanks
# 4        Harrison Ford,Anne Heche,David Schwimmer
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111222_4/132...
# 1  https://movie-phinf.pstatic.net/20111223_268/1...
# 2  https://movie-phinf.pstatic.net/20150803_71/14...
# ...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_nearest neighbor collaborative filtering.csv'
nearest_neighbor_collaborative_filtering_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_nearest neighbor collaborative filtering.csv')
nearest_neighbor_collaborative_filtering_df.head()
# Out:
#    rank  movieId                     title         title_kor  pred_score  \
# 0     1      380                 True Lies            트루 라이즈    5.964701
# 1     2       34                      Babe         꼬마 돼지 베이브    5.701023
# 2     3      349  Clear And Present Danger             긴급 명령    5.195154
# 3     4      586                Home Alone           나 홀로 집에    5.081094
# 4     5      329    Star Trek: Generations  스타 트랙 7 - 넥서스 트랙    4.982579
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111222_243/1...
# 1  https://movie-phinf.pstatic.net/20111222_269/1...
# 2  https://movie-phinf.pstatic.net/20111222_48/13...
# 3  https://movie-phinf.pstatic.net/20111222_256/1...
# 4  https://movie-phinf.pstatic.net/20130422_146/1...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_Latent Factor Collaborative Filtering_list.csv'
Latent_Factor_Collaborative_Filtering_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_Latent Factor Collaborative Filtering_list.csv')
Latent_Factor_Collaborative_Filtering_df.head()
# Out:
#    rank  movieId                 title     title_kor  pred_score  \
# 0     1      501                 Naked          네이키드   11.835151
# 1     2     7254  The Butterfly Effect         나비 효과   11.643395
# 2     3     5956     Gangs Of New York      갱스 오브 뉴욕   11.135050
# 3     4     3578             Gladiator        글래디에이터   10.871661
# 4     5    68157  Inglourious Basterds  바스터즈: 거친 녀석들   10.721287
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111221_283/1...
# 1  https://movie-phinf.pstatic.net/20111222_281/1...
# 2  https://movie-phinf.pstatic.net/20111222_151/1...
# 3  https://movie-phinf.pstatic.net/20130419_151/1...
# 4  https://movie-phinf.pstatic.net/20111223_87/13...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_Deep Learning based Recommender Systems_list.csv'
DeepLearning_based_Recommender_Systems_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user288_영화추천리스트/288_Deep Learning based Recommender Systems_list.csv')
DeepLearning_based_Recommender_Systems_df.head()
# Out:
#    movieId                title title_kor  \
# 0        1            Toy Story    토이 스토리
# 1      380            True Lies    트루 라이즈
# 2      608                Fargo        파고
# 3      648  Mission: Impossible   미션 임파서블
# 4     1721              Titanic      타이타닉
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111222_26/13...
# 1  https://movie-phinf.pstatic.net/20111222_243/1...
# 2  https://movie-phinf.pstatic.net/20111221_53/13...
# 3  https://movie-phinf.pstatic.net/20111221_168/1...
# 4  https://movie-phinf.pstatic.net/20181129_107/1...

# %%
nearest_neighbor_collaborative_filtering_df = nearest_neighbor_collaborative_filtering_df[['movieId', 'title', 'title_kor', 'poster_url']]
nearest_neighbor_collaborative_filtering_df['section'] = 1

Latent_Factor_Collaborative_Filtering_df = Latent_Factor_Collaborative_Filtering_df[['movieId', 'title', 'title_kor', 'poster_url']]
Latent_Factor_Collaborative_Filtering_df['section'] = 2

contents_based_filtering_genre_df = contents_based_filtering_genre_df[['movieId', 'title', 'title_kor', 'poster_url']]
contents_based_filtering_genre_df['section'] = 3

contents_based_filtering_dc_df = contents_based_filtering_dc_df[['movieId', 'title', 'title_kor', 'poster_url']]
contents_based_filtering_dc_df['section'] = 4

DeepLearning_based_Recommender_Systems_df = DeepLearning_based_Recommender_Systems_df[['movieId', 'title', 'title_kor', 'poster_url']]
DeepLearning_based_Recommender_Systems_df['section'] = 5
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
user288_recommend_movies = pd.concat([nearest_neighbor_collaborative_filtering_df, Latent_Factor_Collaborative_Filtering_df, contents_based_filtering_genre_df, contents_based_filtering_dc_df, DeepLearning_based_Recommender_Systems_df], axis = 0)
user288_recommend_movies['userID'] = 2
user288_recommend_movies.rename(columns={'movieId':'rec_mv_id'}, inplace=True)
user288_recommend_movies = user288_recommend_movies[['userID', 'section', 'rec_mv_id', 'title', 'title_kor', 'poster_url']]
user288_recommend_movies
# Out:
#    userID  section  rec_mv_id                                        title  \
# 0       2        1      380.0                                    True Lies
# 1       2        1       34.0                                         Babe
# 2       2        1      349.0                     Clear And Present Danger
# 3       2        1      586.0                                   Home Alone
# 4       2        1      329.0                       Star Trek: Generations
# 0       2        2      501.0                                        Naked
# 1       2        2     7254.0                         The Butterfly Effect
# 2       2        2     5956.0                            Gangs Of New York
# 3       2        2     3578.0                                    Gladiator
# 4       2        2    68157.0                         Inglourious Basterds
# 0       2        3     6156.0                             Shanghai Knights
# ...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_contents_based_filtering_list(genre).csv'
contents_based_filtering_genre_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_contents_based_filtering_list(genre).csv')
contents_based_filtering_genre_df.head()
# Out:
#    rank  movieId                             title         title_kor  \
# 0     1   141072                 The Divine Weapon               신기전
# 1     2   131444  Rurouni Kenshin: The Legend Ends  바람의 검심 : 전설의 최후편
# 2     3       86                      White Squall            화이트 스콜
# 3     4   110968                           Pompeii        폼페이: 최후의 날
# 4     5    94780       Snow White And The Huntsman   스노우 화이트 앤 더 헌츠맨
#
#                    genres                                         poster_url
# 0  Action Adventure Drama  https://movie-phinf.pstatic.net/20111222_186/1...
# 1  Action Adventure Drama  https://movie-phinf.pstatic.net/20150223_141/1...
# 2  Action Adventure Drama  https://movie-phinf.pstatic.net/20111222_165/1...
# 3  Action Adventure Drama  https://movie-phinf.pstatic.net/20140213_66/13...
# 4  Action Adventure Drama  https://movie-phinf.pstatic.net/20120529_80/13...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_contents_based_filtering_list(director&cast).csv'
contents_based_filtering_dc_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_contents_based_filtering_list(director&cast).csv')
contents_based_filtering_dc_df.head()
# Out:
#    rank  movieId                 title     title_kor           director  \
# 0     1    590.0    Dances With Wolves        늑대와 춤을      Kevin Costner
# 1     2    296.0          Pulp Fiction         펄프 픽션  Quentin Tarantino
# 2     3  99114.0      Django Unchained    장고:분노의 추적자  Quentin Tarantino
# 3     4  68157.0  Inglourious Basterds  바스터즈: 거친 녀석들  Quentin Tarantino
# 4     5   1089.0        Reservoir Dogs       저수지의 개들  Quentin Tarantino
#
#                                            cast  \
# 0    Kevin Costner,Mary McDonnell,Graham Greene
# 1   John Travolta,Samuel L. Jackson,Uma Thurman
# 2  Jamie Foxx,Christoph Waltz,Leonardo DiCaprio
# 3     Brad Pitt,Mélanie Laurent,Christoph Waltz
# 4         Harvey Keitel,Tim Roth,Michael Madsen
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20210106_266/1...
# 1  https://movie-phinf.pstatic.net/20111221_33/13...
# 2  https://movie-phinf.pstatic.net/20130204_279/1...
# ...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_nearest neighbor collaborative filtering.csv'
nearest_neighbor_collaborative_filtering_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_nearest neighbor collaborative filtering.csv')
nearest_neighbor_collaborative_filtering_df.head()
# Out:
#    rank  movieId          title  title_kor  pred_score  \
# 0     1      316       Stargate      스타게이트    4.052928
# 1     2      588        Aladdin        알라딘    3.869498
# 2     3       10      GoldenEye  007 골든 아이    3.813398
# 3     4      208     Waterworld       워터월드    3.812109
# 4     5      480  Jurassic Park     쥬라기 공원    3.726482
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111221_240/1...
# 1  https://movie-phinf.pstatic.net/20170418_64/14...
# 2  https://movie-phinf.pstatic.net/20111222_264/1...
# 3  https://movie-phinf.pstatic.net/20111221_9/132...
# 4  https://movie-phinf.pstatic.net/20130531_210/1...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_Latent Factor Collaborative Filtering_list.csv'
Latent_Factor_Collaborative_Filtering_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_Latent Factor Collaborative Filtering_list.csv')
Latent_Factor_Collaborative_Filtering_df.head()
# Out:
#    rank  movieId                            title  title_kor  pred_score  \
# 0     1     6003  Confessions Of A Dangerous Mind        컨페션   10.779800
# 1     2      501                            Naked       네이키드   10.529742
# 2     3     1255                        Bad Taste  고무 인간의 최후   10.413381
# 3     4      608                            Fargo         파고   10.285932
# 4     5       28                       Persuasion         설득   10.182179
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111222_90/13...
# 1  https://movie-phinf.pstatic.net/20111221_283/1...
# 2  https://movie-phinf.pstatic.net/20111222_165/1...
# 3  https://movie-phinf.pstatic.net/20111221_53/13...
# 4  https://movie-phinf.pstatic.net/20111222_268/1...

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_Deep Learning based Recommender Systems_list.csv'
DeepLearning_based_Recommender_Systems_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/modeling/user64_영화추천리스트/64_Deep Learning based Recommender Systems_list.csv')
DeepLearning_based_Recommender_Systems_df.head()
# Out:
#    movieId                       title     title_kor  \
# 0        1                   Toy Story        토이 스토리
# 1      480               Jurassic Park        쥬라기 공원
# 2      588                     Aladdin           알라딘
# 3      589  Terminator 2: Judgment Day  터미네이터 2:오리지널
# 4      608                       Fargo            파고
#
#                                           poster_url
# 0  https://movie-phinf.pstatic.net/20111222_26/13...
# 1  https://movie-phinf.pstatic.net/20130531_210/1...
# 2  https://movie-phinf.pstatic.net/20170418_64/14...
# 3  https://movie-phinf.pstatic.net/20191010_99/15...
# 4  https://movie-phinf.pstatic.net/20111221_53/13...

# %%
nearest_neighbor_collaborative_filtering_df = nearest_neighbor_collaborative_filtering_df[['movieId', 'title', 'title_kor', 'poster_url']]
nearest_neighbor_collaborative_filtering_df['section'] = 1

Latent_Factor_Collaborative_Filtering_df = Latent_Factor_Collaborative_Filtering_df[['movieId', 'title', 'title_kor', 'poster_url']]
Latent_Factor_Collaborative_Filtering_df['section'] = 2

contents_based_filtering_genre_df = contents_based_filtering_genre_df[['movieId', 'title', 'title_kor', 'poster_url']]
contents_based_filtering_genre_df['section'] = 3

contents_based_filtering_dc_df = contents_based_filtering_dc_df[['movieId', 'title', 'title_kor', 'poster_url']]
contents_based_filtering_dc_df['section'] = 4

DeepLearning_based_Recommender_Systems_df = DeepLearning_based_Recommender_Systems_df[['movieId', 'title', 'title_kor', 'poster_url']]
DeepLearning_based_Recommender_Systems_df['section'] = 5
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
user64_recommend_movies = pd.concat([nearest_neighbor_collaborative_filtering_df, Latent_Factor_Collaborative_Filtering_df, contents_based_filtering_genre_df, contents_based_filtering_dc_df, DeepLearning_based_Recommender_Systems_df], axis = 0)
user64_recommend_movies['userID'] = 64
user64_recommend_movies.rename(columns={'movieId':'rec_mv_id'}, inplace=True)
user64_recommend_movies = user64_recommend_movies[['userID', 'section', 'rec_mv_id', 'title', 'title_kor', 'poster_url']]
user64_recommend_movies
# Out:
#    userID  section  rec_mv_id                             title  \
# 0      64        1      316.0                          Stargate
# 1      64        1      588.0                           Aladdin
# 2      64        1       10.0                         GoldenEye
# 3      64        1      208.0                        Waterworld
# 4      64        1      480.0                     Jurassic Park
# 0      64        2     6003.0   Confessions Of A Dangerous Mind
# 1      64        2      501.0                             Naked
# 2      64        2     1255.0                         Bad Taste
# 3      64        2      608.0                             Fargo
# 4      64        2       28.0                        Persuasion
# 0      64        3   141072.0                 The Divine Weapon
# 1      64        3   131444.0  Rurouni Kenshin: The Legend Ends
# 2      64        3       86.0                      White Squall
# 3      64        3   110968.0                           Pompeii
# ...

# %%
# final_recommend_movies = pd.concat([user213_recommend_movies, user475_recommend_movies, user288_recommend_movies, user64_recommend_movies], axis = 0)

final_recommend_movies = pd.concat([user213_recommend_movies, user288_recommend_movies], axis = 0)
final_recommend_movies.drop(columns=['title'], axis=1, inplace=True)

final_recommend_movies.rename(columns={'rec_mv_id':'movieId'}, inplace=True)
final_recommend_movies = final_recommend_movies.astype({'movieId' : int})

final_recommend_movies.reset_index(drop = True, inplace = True)
final_recommend_movies.reset_index(inplace = True)
final_recommend_movies['index'] = final_recommend_movies['index'] + 1
final_recommend_movies
# Out:
#     index  userID  section  movieId         title_kor  \
# 0       1       1        1       10         007 골든 아이
# 1       2       1        1    68954                 업
# 2       3       1        1      329  스타 트랙 7 - 넥서스 트랙
# 3       4       1        1   115617             빅 히어로
# 4       5       1        1      434             클리프행어
# 5       6       1        2     5903            이퀼리브리엄
# 6       7       1        2      198         스트레인지 데이즈
# 7       8       1        2    40819               앙코르
# 8       9       1        2   134130                마션
# 9      10       1        2    98961          제로 다크 서티
# 10     11       1        3      480            쥬라기 공원
# 11     12       1        3    61248            데스 레이스
# 12     13       1        3   127323               바이스
# 13     14       1        3   120799        터미네이터 제니시스
# 14     15       1        3    70336   지.아이.조 - 전쟁의 서막
# 15     16       1        4   102445         스타트렉 다크니스
# ...

# %%
final_recommend_movies.to_csv("recommend_movies.csv", mode='w', index=False)

# %%
filename = '/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/Data Preprocessing/movie_dataset.csv'
movies_df = pd.read_csv('/content/drive/MyDrive/bigdata_analysis_final_project - movie recommender system(영화 추천 시스템)/Data Preprocessing/movie_dataset.csv')
movies_df.head()
# Out:
#    movieId  naver_code                        title  title_kor  \
# 0        1       17153                    Toy Story     토이 스토리
# 1        2       17440                      Jumanji        쥬만지
# 2        4       17798            Waiting To Exhale   사랑을 기다리며
# 3        5       17754  Father Of The Bride Part II  신부의 아버지 2
# 4        6       17327                         Heat         히트
#
#                                         genres  \
# 0  Adventure Animation Children Comedy Fantasy
# 1                   Adventure Children Fantasy
# 2                         Comedy Drama Romance
# 3                                       Comedy
# 4                        Action Crime Thriller
#
#                                              keyword         director  \
# 0  jealousy,toy,boy,friendship,friends,rivalry,bo...    John Lasseter
# 1  board game,disappearance,based on children's b...     Joe Johnston
# 2  based on novel,interracial relationship,single...  Forest Whitaker
# ...

# %%
movies_df2 = movies_df[['movieId', 'naver_code']]

# %%
final_recommend_movies2 = same_movie_df1 = pd.merge(final_recommend_movies, movies_df2, how = 'inner', on=['movieId'])
final_recommend_movies2 = final_recommend_movies2[['index', 'userID', 'section', 'naver_code', 'title_kor', 'poster_url']]
final_recommend_movies2.rename(columns={'naver_code':'rec_mv_id'}, inplace=True)
final_recommend_movies2.sort_values('index', inplace = True)
final_recommend_movies2
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     index  userID  section  rec_mv_id         title_kor  \
# 0       1       1        1      17149         007 골든 아이
# 1       2       1        1      52120                 업
# 2       3       1        1      17500  스타 트랙 7 - 넥서스 트랙
# 4       4       1        1     109911             빅 히어로
# ...

# %%
final_recommend_movies2.to_csv("recommend_movies_db.csv", mode='w', index=False)
